# %%
cd /content/drive/MyDrive/Colab Notebooks/Curso RNA/Red Neuronal con Numpy
# Out:
# /content/drive/MyDrive/Colab Notebooks/Curso RNA/Red Neuronal con Numpy

# %%
ls
# Out:
# Consola.ipynb         ejemplo.py       mnist.pkl.gz  Numero3.jpg   red_prueba1.pkl
# DataVisualization.py  mnist_loader.py  network.py    __pycache__/  UsandoNetwork.py

# %%
# !python ejemplo.py
# Out:
# Epoch 0: 9083 / 10000
# Epoch 1: 9224 / 10000
# Epoch 2: 9282 / 10000
# Epoch 3: 9338 / 10000
# Epoch 4: 9382 / 10000
# Epoch 5: 9396 / 10000
# Epoch 6: 9383 / 10000
# Epoch 7: 9430 / 10000
# Epoch 8: 9457 / 10000
# Epoch 9: 9429 / 10000
# Epoch 10: 9471 / 10000
# Epoch 11: 9480 / 10000
# Epoch 12: 9457 / 10000
# Epoch 13: 9484 / 10000
# Epoch 14: 9480 / 10000
# Epoch 15: 9486 / 10000
# Epoch 16: 9466 / 10000
# Epoch 17: 9494 / 10000
# Epoch 18: 9489 / 10000
# Epoch 19: 9520 / 10000
# Epoch 20: 9507 / 10000
# Epoch 21: 9495 / 10000
# Epoch 22: 9500 / 10000
# Epoch 23: 9486 / 10000
# Epoch 24: 9484 / 10000
# Epoch 25: 9500 / 10000
# Epoch 26: 9492 / 10000
# Epoch 27: 9501 / 10000
# Epoch 28: 9500 / 10000
# Epoch 29: 9474 / 10000

# %%
# !python DataVisualization.py
# Out:
# 5
# Figure(640x480)
# imagen a reconocer
# Figure(640x480)
# [[1.14828360e-01]
#  [8.55959230e-06]
#  [4.25644824e-08]
#  [2.21773469e-01]
#  [4.43452865e-09]
#  [3.68203014e-04]
#  [7.41437507e-09]
#  [2.37596010e-07]
#  [3.91468623e-09]
#  [2.30931808e-08]]
# La red reconoce la imagen como un:
# [3]
# Ahora probamos con la imagen del 5 de la base de datos:
# [[1.88575153e-09]
#  [6.60929345e-05]
#  [1.55658905e-05]
#  [6.52917893e-01]
#  [1.11656007e-12]
#  [9.50971698e-01]
#  [1.35766605e-10]
#  [1.77070457e-03]
#  [2.00653238e-06]
#  [6.16063492e-10]]
# La red reconoce la imagen como un:
# [5]

# %% [markdown]
# # Para montar gdrive en linux

# %%
sudo apt-get install python-pip
sudo apt-get install build-essential python-dev

# %% [markdown]
# En espacio de usuario para computadoras sin permiso administrativo

# %%
pip install --user gdrivefs

# %% [markdown]
# Autenticación Automática

# %%
gdfstool auth_automatic

# %% [markdown]
# Montar con valores default

# %%
gdfs default /mnt/gdrivefs

# %% [markdown]
# O bien para mayor velocidad (linux)

# %%
gdfs -o big_writes /home/user/.gdfs/creds /mnt/gdrivefs

# %% [markdown]
# O bien consola directo en colab

# %%
# !pip install google-colab-shell
from google_colab_shell import getshell
getshell()
# Out:
# Requirement already satisfied: google-colab-shell in /usr/local/lib/python3.10/dist-packages (0.2)
# <!--https://github.com/singhsidhukuldeep/Google-Colab-Shell/-->
# <!--Using JS/CSS from official sources with backups in-case :)-->
# <div id=colab_shell></div>
# <script src="https://code.jquery.com/jquery-latest.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/jquery.terminal/js/jquery.terminal.min.js"></script>
# <link href="https://cdn.jsdelivr.net/npm/jquery.terminal/css/jquery.terminal.min.css" rel="stylesheet"/>
# <script>
#    $('#colab_shell').terminal(async function(command) {
#        if (command !== '') {
#            try {
#                let res = await google.colab.kernel.invokeFunction('shell', [command])
#                let out = res.data['application/json'][0]
#                this.echo(new String(out))
#            } catch(e) {
#                this.error(new String(e));
#            }
#        } else {
#            this.echo(
#              //   '>>Empty Command<<\n'+
#              //   'If you can afford use Google Colab Pro'
#                );
#        }
#    }, {
#        greetings: 'Welcome to Google Colab Shell\n'+
#          'If you can afford, please use Google Colab Pro ( https://colab.research.google.com/signup )\n'+
#          '⭐ STAR the repo ⭐\n https://github.com/singhsidhukuldeep/Google-Colab-Shell\n\n',
#        name: 'colab_shell',
#        height: 400,
#        prompt: '█$ colab>>\t'
#    });
# </script>
