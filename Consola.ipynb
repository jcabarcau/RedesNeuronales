# %%
cd C:/Users/Carlos/Desktop/GitHub/RedesNeuronales
# Out:
# C:\Users\Carlos\Desktop\GitHub\RedesNeuronales
# C:\Users\Carlos\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2CF3-2C31
#
#  Directory of C:\Users\Carlos\Desktop\GitHub\RedesNeuronales
#
# 06/02/2024  10:32    <DIR>          .
# 06/02/2024  10:32    <DIR>          ..
# 23/01/2024  18:23                66 .gitattributes
# 06/02/2024  10:14    <DIR>          __pycache__
# 06/02/2024  10:32             7,407 Consola.ipynb
# 25/01/2024  09:58             2,223 DataVisualization.py
# 06/02/2024  10:22               721 ejemplo.py
# 25/01/2024  09:58               955 ejemplo_comentado.py
# 25/03/2021  11:40        17,051,982 mnist.pkl.gz
# 18/01/2024  19:33             3,509 mnist_loader.py
# 06/02/2024  09:38             4,239 network.py
# 06/02/2024  10:19            16,543 network_comentado.py
# 11/11/2021  09:50            88,484 Numero3.jpg
# 23/01/2024  18:23                87 README.md
# 06/02/2024  10:30           191,232 red_prueba1.pkl
# 18/01/2024  19:26               386 UsandoNetwork.py
#               13 File(s)     17,367,834 bytes
#                3 Dir(s)  112,622,014,464 bytes free

# %%
# !python network.py

# %%
# !python ejemplo.py
# Out:
# ^C
# Epoch 0: 8937 / 10000
# Epoch 1: 9145 / 10000
# Epoch 2: 9248 / 10000
# Epoch 3: 9277 / 10000
# Epoch 4: 9314 / 10000
# Epoch 5: 9377 / 10000
# Epoch 6: 9364 / 10000
# Epoch 7: 9372 / 10000
# Epoch 8: 9388 / 10000
# Epoch 9: 9371 / 10000
# Epoch 10: 9415 / 10000
# Epoch 11: 9427 / 10000
# Epoch 12: 9419 / 10000
# Epoch 13: 9431 / 10000
# Epoch 14: 9436 / 10000
# Epoch 15: 9447 / 10000
# Epoch 16: 9447 / 10000
# Epoch 17: 9442 / 10000
# Epoch 18: 9446 / 10000
# Epoch 19: 9452 / 10000
# Epoch 20: 9461 / 10000
# Epoch 21: 9456 / 10000
# Epoch 22: 9466 / 10000
# Epoch 23: 9452 / 10000
# Epoch 24: 9446 / 10000
# Epoch 25: 9464 / 10000
# Epoch 26: 9469 / 10000
# Epoch 27: 9479 / 10000
# Epoch 28: 9474 / 10000
# Epoch 29: 9474 / 10000
# Epoch 30: 9471 / 10000
# Epoch 31: 9475 / 10000
# Epoch 32: 9484 / 10000
# Epoch 33: 9476 / 10000
# Epoch 34: 9467 / 10000
# Epoch 35: 9468 / 10000
# Epoch 36: 9482 / 10000
# Epoch 37: 9474 / 10000
# Epoch 38: 9479 / 10000
# Epoch 39: 9465 / 10000
# Epoch 40: 9474 / 10000
# Epoch 41: 9477 / 10000
# Epoch 42: 9481 / 10000
# Epoch 43: 9488 / 10000
# Epoch 44: 9484 / 10000
# Epoch 45: 9487 / 10000
# Epoch 46: 9481 / 10000
# Epoch 47: 9480 / 10000
# Epoch 48: 9476 / 10000
# Epoch 49: 9475 / 10000

# %%
# !python DataVisualization.py
# Out:
# 5
# Figure(640x480)
# imagen a reconocer
# Figure(640x480)
# [[1.14828360e-01]
#  [8.55959230e-06]
#  [4.25644824e-08]
#  [2.21773469e-01]
#  [4.43452865e-09]
#  [3.68203014e-04]
#  [7.41437507e-09]
#  [2.37596010e-07]
#  [3.91468623e-09]
#  [2.30931808e-08]]
# La red reconoce la imagen como un:
# [3]
# Ahora probamos con la imagen del 5 de la base de datos:
# [[1.88575153e-09]
#  [6.60929345e-05]
#  [1.55658905e-05]
#  [6.52917893e-01]
#  [1.11656007e-12]
#  [9.50971698e-01]
#  [1.35766605e-10]
#  [1.77070457e-03]
#  [2.00653238e-06]
#  [6.16063492e-10]]
# La red reconoce la imagen como un:
# [5]

# %% [markdown]
# # Para montar gdrive en linux

# %%
sudo apt-get install python-pip
sudo apt-get install build-essential python-dev

# %% [markdown]
# En espacio de usuario para computadoras sin permiso administrativo

# %%
pip install --user gdrivefs

# %% [markdown]
# Autenticación Automática

# %%
gdfstool auth_automatic

# %% [markdown]
# Montar con valores default

# %%
gdfs default /mnt/gdrivefs

# %% [markdown]
# O bien para mayor velocidad (linux)

# %%
gdfs -o big_writes /home/user/.gdfs/creds /mnt/gdrivefs

# %% [markdown]
# O bien consola directo en colab

# %%
# !pip install google-colab-shell
from google_colab_shell import getshell
getshell()
# Out:
# Requirement already satisfied: google-colab-shell in /usr/local/lib/python3.10/dist-packages (0.2)
# <!--https://github.com/singhsidhukuldeep/Google-Colab-Shell/-->
# <!--Using JS/CSS from official sources with backups in-case :)-->
# <div id=colab_shell></div>
# <script src="https://code.jquery.com/jquery-latest.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/jquery.terminal/js/jquery.terminal.min.js"></script>
# <link href="https://cdn.jsdelivr.net/npm/jquery.terminal/css/jquery.terminal.min.css" rel="stylesheet"/>
# <script>
#    $('#colab_shell').terminal(async function(command) {
#        if (command !== '') {
#            try {
#                let res = await google.colab.kernel.invokeFunction('shell', [command])
#                let out = res.data['application/json'][0]
#                this.echo(new String(out))
#            } catch(e) {
#                this.error(new String(e));
#            }
#        } else {
#            this.echo(
#              //   '>>Empty Command<<\n'+
#              //   'If you can afford use Google Colab Pro'
#                );
#        }
#    }, {
#        greetings: 'Welcome to Google Colab Shell\n'+
#          'If you can afford, please use Google Colab Pro ( https://colab.research.google.com/signup )\n'+
#          '⭐ STAR the repo ⭐\n https://github.com/singhsidhukuldeep/Google-Colab-Shell\n\n',
#        name: 'colab_shell',
#        height: 400,
#        prompt: '█$ colab>>\t'
#    });
# </script>
